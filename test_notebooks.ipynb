# %%
import agent
import json
from pprint import pprint

response = agent.invoke_query("Make fundamental analysis on top 3 stocks by capital and tell me if it's worth to invest. Use benjamin graham's principles.")

pprint(response)
# Out:
# {'messages': [HumanMessage(content="Make fundamental analysis on top 3 stocks by capital and tell me if it's worth to invest. Use benjamin graham's principles.", additional_kwargs={}, response_metadata={}, id='cdbbca8d-9c84-4368-bbec-57520fda7007'),
# ...

# %%
print(response["messages"][1].content)
# Out:
# I can certainly help you with a fundamental analysis of the top 3 stocks by market capitalization, using Benjamin Graham's principles, to determine if they might be worth investing in. However, to provide you with the most accurate and personalized recommendation, I need a bit more information.
#
# **Please tell me:**
#
# 1.  **What is your investment goal?** (e.g., long-term wealth growth, income generation, capital preservation, a specific future purchase like a house or retirement?)
# 2.  **What is your risk tolerance?** (e.g., low, medium, high? Are you comfortable with significant fluctuations in value for potentially higher returns, or do you prefer stability?)
# 3.  **What is your time horizon for this investment?** (e.g., short-term (1-3 years), medium-term (3-7 years), long-term (7+ years)?)
#
# Once I have this information, I can proceed with the analysis.
#
# **In the meantime, here's how I plan to approach the fundamental analysis using Benjamin Graham's principles:**
#
# ...
